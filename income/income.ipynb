# %% [markdown]
# ##Context:
#
# According to [NPR.org](http://www.npr.org/blogs/money/2015/02/11/384988128/the-fall-and-rise-of-u-s-inequality-in-2-graphs), "After 1980, only the top 1% saw their incomes rise." [Flowing Data](http://flowingdata.com/2015/02/20/top-1-earners-versus-bottom-90/) quoted this figure:
#
# ![](http://flowingdata.com/wp-content/uploads/2015/02/Earners-620x560.png)
#
# Their source came from [World Top Incomes Database](http://topincomes.parisschoolofeconomics.eu/#Database).
#
# I decided to double-check it using a [dataset](https://www.census.gov/hhes/www/income/data/historical/families/2013/f03AR.xls) from census.gov

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
sns.set(context="poster", style="dark")
import mpld3

# %%
# csv location = 
income_df = pd.read_csv("income_2013_dollars.csv", sep='\t', thousands=',')
income_df.columns = ["year", "lowest fifth", "second fifth", "third fifth", "fourth fifth", "top fifth", "top 5%"]
income_df.sort(columns="year", inplace=True)
income_df.head()
# Out:
#     year  lowest fifth  second fifth  third fifth  fourth fifth  top fifth  \
# 47  1966         14747         32739        46844         62710     107026
# 46  1967         14977         33490        48138         64560     113997
# 45  1968         16143         35208        50300         67270     114947
# 44  1969         16656         36783        52635         70510     120757
# 43  1970         16404         36271        52445         70744     121652
#
#     top 5%
# 47  164340
# 46  180362
# 45  177194
# 44  185476
# 43  185243

# %%
income_df.tail()
# Out:
#    year  lowest fifth  second fifth  third fifth  fourth fifth  top fifth  \
# 4  2009         16604         40232        65061         98788     205788
# 3  2010         15944         39436        64276         98064     199918
# 2  2011         15828         38898        63212         96563     205003
# 1  2012         15760         38739        63372         96861     205503
# 0  2013         16109         39514        63916         97207     206687
#
#    top 5%
# 4  352985
# 3  334275
# 2  356839
# 1  357458
# 0  358722

# %%
ax = income_df.plot(x="year")
ax.set_ylabel("income")
ax.set_xlabel("year")
print("feel free to interact with the graph:")
mpld3.display()
# Out:
# feel free to interact with the graph:
# <style>
#
# </style>
#
# <div id="fig_el183831398456772337683278460889"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el183831398456772337683278460889", {"axes": [{"lines": [{"color": "#4C72B0", "zorder": 2, "id": "el18383139845674508976", "alpha": 1, "data": "data01", "coordinates": "data", "yindex": 1, "linewidth": 2.8000000000000003, "dasharray": "10,0", "xindex": 0}, {"color": "#55A868", "zorder": 2, "id": "el18383139845676845880", "alpha": 1, "data": "data01", "coordinates": "data", "yindex": 2, "linewidth": 2.8000000000000003, "dasharray": "10,0", "xindex": 0}, {"color": "#C44E52", "zorder": 2, "id": "el18383139845676845264", "alpha": 1, "data": "data01", "coordinates": "data", "yindex": 3, "linewidth": 2.8000000000000003, "dasharray": "10,0", "xindex": 0}, {"color": "#8172B2", "zorder": 2, "id": "el18383139845676936496", "alpha": 1, "data": "data01", "coordinates": "data", "yindex": 4, "linewidth": 2.8000000000000003, "dasharray": "10,0", "xindex": 0}, {"color": "#CCB974", "zorder": 2, "id": "el18383139845677074976", "alpha": 1, "data": "data01", "coordinates": "data", "yindex": 5, "linewidth": 2.8000000000000003, "dasharray": "10,0", "xindex": 0}, {"color": "#64B5CD", "zorder": 2, "id": "el18383139845677076320", "alpha": 1, "data": "data01", "coordinates": "data", "yindex": 6, "linewidth": 2.8000000000000003, "dasharray": "10,0", "xindex": 0}, {"color": "#4C72B0", "zorder": 1000002.0, "id": "el18383139845671482536", "alpha": 1, "data": "data02", "coordinates": "axes", "yindex": 1, "linewidth": 2.8000000000000003, "dasharray": "10,0", "xindex": 0}, {"color": "#55A868", "zorder": 1000002.0, "id": "el18383139845674498368", "alpha": 1, "data": "data02", "coordinates": "axes", "yindex": 2, "linewidth": 2.8000000000000003, "dasharray": "10,0", "xindex": 0}, {"color": "#C44E52", "zorder": 1000002.0, "id": "el18383139845674498872", "alpha": 1, "data": "data02", "coordinates": "axes", "yindex": 3, "linewidth": 2.8000000000000003, "dasharray": "10,0", "xindex": 0}, {"color": "#8172B2", "zorder": 1000002.0, "id": "el18383139845677076888", "alpha": 1, "data": "data02", "coordinates": "axes", "yindex": 4, "linewidth": 2.8000000000000003, "dasharray": "10,0", "xindex": 0}, {"color": "#CCB974", "zorder": 1000002.0, "id": "el18383139845676999064", "alpha": 1, "data": "data02", "coordinates": "axes", "yindex": 5, "linewidth": 2.8000000000000003, "dasharray": "10,0", "xindex": 0}, {"color": "#64B5CD", "zorder": 1000002.0, "id": "el18383139845674670960", "alpha": 1, "data": "data02", "coordinates": "axes", "yindex": 6, "linewidth": 2.8000000000000003, "dasharray": "10,0", "xindex": 0}], "images": [], "paths": [{"xindex": 0, "yindex": 1, "edgewidth": 0.48, "data": "data03", "dasharray": "10,0", "zorder": 1000001.0, "pathcodes": ["M", "L", "L", "L", "Z"], "alpha": 1.0, "facecolor": "#EAEAF2", "coordinates": "axes", "id": "el18383139845671482928", "edgecolor": "#FFFFFF"}], "xdomain": [1966.0, 2013.0], "axesbg": "#EAEAF2", "axesbgalpha": null, "collections": [], "ylim": [0.0, 400000.0], "id": "el18383139845677100000", "sharey": [], "axes": [{"tickvalues": null, "fontsize": 16.0, "position": "bottom", "grid": {"color": "#FFFFFF", "gridOn": true, "alpha": 1.0, "dasharray": "10,0"}, "tickformat": null, "scale": "linear", "nticks": 7}, {"tickvalues": null, "fontsize": 16.0, "position": "left", "grid": {"color": "#FFFFFF", "gridOn": true, "alpha": 1.0, "dasharray": "10,0"}, "tickformat": null, "scale": "linear", "nticks": 9}], "ydomain": [0.0, 400000.0], "bbox": [0.125, 0.125, 0.775, 0.775], "markers": [], "texts": [{"color": "#262626", "rotation": -0.0, "fontsize": 17.6, "v_baseline": "hanging", "position": [0.5, -0.06414956011730205], "zorder": 3, "alpha": 1, "text": "year", "coordinates": "axes", "id": "el18383139845676244552", "h_anchor": "middle"}, {"color": "#262626", "rotation": -90.0, "fontsize": 17.6, "v_baseline": "auto", "position": [-0.09610083795362903, 0.5], "zorder": 3, "alpha": 1, "text": "income", "coordinates": "axes", "id": "el18383139845676159440", "h_anchor": "middle"}, {"color": "#262626", "rotation": -0.0, "fo ...

# %% [markdown]
# ###Slightly different story from "after 1980, only the top 1% saw their incomes rise."
#
# This is all beside the fact that neither NPR's nor the above graph show mobility. I.e., someone in 1970 and today is unlikely to belong to the same "income class".
