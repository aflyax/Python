# %% [markdown]
# ##Context:
#
# According to [NPR.org](http://www.npr.org/blogs/money/2015/02/11/384988128/the-fall-and-rise-of-u-s-inequality-in-2-graphs), "After 1980, only the top 1% saw their incomes rise." [Flowing Data](http://flowingdata.com/2015/02/20/top-1-earners-versus-bottom-90/) quoted this figure:
#
# ![](http://flowingdata.com/wp-content/uploads/2015/02/Earners-620x560.png)
#
# Their source came from [World Top Incomes Database](http://topincomes.parisschoolofeconomics.eu/#Database).
#
# I decided to double-check it using a [dataset](https://www.census.gov/hhes/www/income/data/historical/families/2013/f03AR.xls) from census.gov

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
sns.set(context="poster", style="dark")
import mpld3

# %%
# csv location = https://github.com/aflyax/Python/blob/master/income/income_2013_dollars.csv
income_df = pd.read_csv("income_2013_dollars.csv", sep='\t', thousands=',')
income_df.columns = ["year", "lowest fifth", "second fifth", "third fifth", "fourth fifth", "top fifth", "top 5%"]
income_df.sort(columns="year", inplace=True)
income_df.head()
# Out:
#     year  lowest fifth  second fifth  third fifth  fourth fifth  top fifth  \
# 47  1966         14747         32739        46844         62710     107026
# 46  1967         14977         33490        48138         64560     113997
# 45  1968         16143         35208        50300         67270     114947
# 44  1969         16656         36783        52635         70510     120757
# 43  1970         16404         36271        52445         70744     121652
#
#     top 5%
# 47  164340
# 46  180362
# 45  177194
# 44  185476
# 43  185243

# %%
income_df.tail()
# Out:
#    year  lowest fifth  second fifth  third fifth  fourth fifth  top fifth  \
# 4  2009         16604         40232        65061         98788     205788
# 3  2010         15944         39436        64276         98064     199918
# 2  2011         15828         38898        63212         96563     205003
# 1  2012         15760         38739        63372         96861     205503
# 0  2013         16109         39514        63916         97207     206687
#
#    top 5%
# 4  352985
# 3  334275
# 2  356839
# 1  357458
# 0  358722

# %%
ax = income_df.plot(x="year")
ax.set_ylabel("income")
ax.set_xlabel("year")
print("feel free to interact with the graph:")
mpld3.display()
# Out:
# feel free to interact with the graph:
# <style>
#
# </style>
#
# <div id="fig_el210401401944694270726238410456"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el210401401944694270726238410456", {"plugins": [{"type": "reset"}, {"button": true, "enabled": false, "type": "zoom"}, {"button": true, "enabled": false, "type": "boxzoom"}], "axes": [{"xdomain": [1966.0, 2013.0], "xlim": [1966.0, 2013.0], "yscale": "linear", "collections": [], "lines": [{"zorder": 2, "color": "#4C72B0", "data": "data01", "xindex": 0, "dasharray": "10,0", "yindex": 1, "id": "el21040140194468504968", "alpha": 1, "coordinates": "data", "linewidth": 2.8000000000000003}, {"zorder": 2, "color": "#55A868", "data": "data01", "xindex": 0, "dasharray": "10,0", "yindex": 2, "id": "el21040140194468817272", "alpha": 1, "coordinates": "data", "linewidth": 2.8000000000000003}, {"zorder": 2, "color": "#C44E52", "data": "data01", "xindex": 0, "dasharray": "10,0", "yindex": 3, "id": "el21040140194468760656", "alpha": 1, "coordinates": "data", "linewidth": 2.8000000000000003}, {"zorder": 2, "color": "#8172B2", "data": "data01", "xindex": 0, "dasharray": "10,0", "yindex": 4, "id": "el21040140194468506032", "alpha": 1, "coordinates": "data", "linewidth": 2.8000000000000003}, {"zorder": 2, "color": "#CCB974", "data": "data01", "xindex": 0, "dasharray": "10,0", "yindex": 5, "id": "el21040140194468569552", "alpha": 1, "coordinates": "data", "linewidth": 2.8000000000000003}, {"zorder": 2, "color": "#64B5CD", "data": "data01", "xindex": 0, "dasharray": "10,0", "yindex": 6, "id": "el21040140194468571568", "alpha": 1, "coordinates": "data", "linewidth": 2.8000000000000003}, {"zorder": 1000002.0, "color": "#4C72B0", "data": "data02", "xindex": 0, "dasharray": "10,0", "yindex": 1, "id": "el21040140194468595920", "alpha": 1, "coordinates": "axes", "linewidth": 2.8000000000000003}, {"zorder": 1000002.0, "color": "#55A868", "data": "data02", "xindex": 0, "dasharray": "10,0", "yindex": 2, "id": "el21040140194468627288", "alpha": 1, "coordinates": "axes", "linewidth": 2.8000000000000003}, {"zorder": 1000002.0, "color": "#C44E52", "data": "data02", "xindex": 0, "dasharray": "10,0", "yindex": 3, "id": "el21040140194468629920", "alpha": 1, "coordinates": "axes", "linewidth": 2.8000000000000003}, {"zorder": 1000002.0, "color": "#8172B2", "data": "data02", "xindex": 0, "dasharray": "10,0", "yindex": 4, "id": "el21040140194468653096", "alpha": 1, "coordinates": "axes", "linewidth": 2.8000000000000003}, {"zorder": 1000002.0, "color": "#CCB974", "data": "data02", "xindex": 0, "dasharray": "10,0", "yindex": 5, "id": "el21040140194468663984", "alpha": 1, "coordinates": "axes", "linewidth": 2.8000000000000003}, {"zorder": 1000002.0, "color": "#64B5CD", "data": "data02", "xindex": 0, "dasharray": "10,0", "yindex": 6, "id": "el21040140194468664432", "alpha": 1, "coordinates": "axes", "linewidth": 2.8000000000000003}], "ydomain": [0.0, 400000.0], "axesbg": "#EAEAF2", "texts": [{"position": [0.5, -0.06414956011730205], "rotation": -0.0, "alpha": 1, "text": "year", "zorder": 3, "color": "#262626", "fontsize": 17.6, "id": "el21040140194469008552", "v_baseline": "hanging", "coordinates": "axes", "h_anchor": "middle"}, {"position": [-0.09610083795362903, 0.5], "rotation": -90.0, "alpha": 1, "text": "income", "zorder": 3, "color": "#262626", "fontsize": 17.6, "id": "el21040140194468783832", "v_baseline": "auto", "coordinates": "axes", "h_anchor": "middle"}, {"position": [0.0828853046594982, 0.9468475073313781], "rotation": -0.0, "alpha": 1, "text": "lowest fifth", "zorder": 1000003.0, "color": "#262626", "fontsize": 16.0, "id": "el21040140194468594744", "v_baseline": "auto", "coordinates": "axes", "h_anchor": "start"}, {"position": [0.0828853046594982, 0.8993971977842944], "rotation": -0.0, "alpha": 1, "text": "second fifth", "zorder": 1000003.0, "color": "#262626", "fontsize": 16.0, "id": "el21040140194468597432", "v_baseline": "auto", "coordinates": "axes", "h_anchor": "start"}, {"position": [0.0828853046594982, 0.8519468882372104], "rotation": -0.0, "alpha": 1, "text": "third fifth", "zorder": 1000003.0, "color": "#262626", "fonts ...

# %% [markdown]
# ###Slightly different story from "after 1980, only the top 1% saw their incomes rise."
#
# This is all beside the point that neither NPR's nor the above graph show mobility. I.e., the same person in 1970 and today is unlikely to belong to the same "income class".
