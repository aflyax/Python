# %% [markdown]
# ####"Unbiased America" Facebook group claims that:
#
# ![](https://fbcdn-sphotos-e-a.akamaihd.net/hphotos-ak-xta1/v/t1.0-9/11055379_347538995432102_7432835378471570158_n.jpg?oh=5a0c4c50b921e6eef57f62d3ceaf09f9&oe=55B9B45D&__gda__=1433759700_e56df7a10e0b89ed75cf90fcf80a8836)
#
#
# ####Let's check if this is true.
#
# ###Sources: [Minimum Wage](https://www.quandl.com/c/economics/minimum-wage-by-country), [Youth Unemployment](https://www.quandl.com/c/economics/youth-unemployment-by-country)
#
# ####scroll down for final figures

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set(context="poster", style="dark")
import mpld3
from mpld3 import plugins

# %%
unemp_df = pd.read_csv("min_wage_unemployment.csv")
print(unemp_df.head())
# Out:
#                Country  Min_wage_month  Unemployment
# 0          Afghanistan               0           NaN
# 1              Albania             201          28.7
# 2              Algeria             211          24.0
# 3               Angola             144           NaN
# 4  Antigua and Barbuda             573          19.9

# %%
print(unemp_df.tail())
# Out:
#        Country  Min_wage_month  Unemployment
# 183  Venezuela             356          16.1
# 184    Vietnam              73           5.4
# 185      Yemen              75          29.8
# 186     Zambia             132          24.6
# 187   Zimbabwe             246           9.3

# %%
df = unemp_df.dropna()
df.reset_index(inplace=True, drop=True)
print(df)
# Out:
#                     Country  Min_wage_month  Unemployment
# 0                   Albania             201          28.7
# 1                   Algeria             211          24.0
# 2       Antigua and Barbuda             573          19.9
# 3                 Argentina             635          19.9
# 4                   Armenia              92          38.3
# 5                 Australia            2104          12.2
# 6                   Austria             726           8.7
# 7                Azerbaijan             112          14.8
# 8                   Bahrain               0          27.9
# 9                Bangladesh             335           9.2
# 10                  Belgium            1744          23.1
# 11                   Belize             386          29.7
# 12                    Benin              62           1.7
# 13                   Bhutan               0           6.7
# 14                  Bolivia             133           4.9
# ...

# %%
# Define some CSS to control our custom labels
css = """
table
{
  border-collapse: collapse;
}
th
{
  color: #ffffff;
  background-color: #000000;
}
td
{
  background-color: #cccccc;
}
table, th, td
{
  font-family:Arial, Helvetica, sans-serif;
  border: 1px solid black;
  text-align: right;
}
"""

fig, ax = plt.subplots()
ax.grid(True, alpha=0.3)

points = ax.plot(df.Min_wage_month, df.Unemployment, '.')

plt.xlim([-100, 4500]);
plt.ylim([-1, 80]);
plt.xlabel("minimum wage (per month), USD")
plt.ylabel("unemployment, %")

labels = []
for i in range(len(df)):
    label = df.ix[[i], :].T
    label.columns = ['Row {0}'.format(i)]
    # .to_html() is unicode; so make leading 'u' go away with str()
    labels.append(str(label.to_html()))


tooltip = plugins.PointHTMLTooltip(points[0], labels,
                                   voffset=10, hoffset=10, css=css)
plugins.connect(fig, tooltip)
plt.title("the world (hover over points for info)")
mpld3.display()
# Out:
# <style>
#
# table
# {
#   border-collapse: collapse;
# }
# th
# {
#   color: #ffffff;
#   background-color: #000000;
# }
# td
# {
#   background-color: #cccccc;
# }
# table, th, td
# {
#   font-family:Arial, Helvetica, sans-serif;
#   border: 1px solid black;
#   text-align: right;
# }
#
# </style>
#
# <div id="fig_el236341400052397450563971876937"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
# ...

# %% [markdown]
# ###^ Feel free to interact with the graph or hover over points for tooltipped info

# %%
west_df = pd.read_csv("min_wage_unemployment_western-europe.csv")

fig, ax = plt.subplots()
ax.grid(True, alpha=0.3)

points = ax.plot(west_df.min_wage, west_df.youth_unemp, 'o', ms=15, mew=1, alpha=.6)

# ax = plt.plot(df.Min_wage_month, df.Unemployment, '.')
plt.xlim([-100, 4500]);
plt.ylim([-1, 60]);
plt.xlabel("minimum wage (per month), USD")
plt.ylabel("younemployment, %")

labels = []
for i in range(len(df)):
    label = west_df.ix[[i], :].T
    label.columns = ['Row {0}'.format(i)]
    # .to_html() is unicode; so make leading 'u' go away with str()
    labels.append(str(label.to_html()))


tooltip = plugins.PointHTMLTooltip(points[0], labels,
                                   voffset=10, hoffset=10, css=css)
plugins.connect(fig, tooltip)
plt.title("Western Europe (hover over points for info)")
mpld3.display()
# Out:
# <style>
#
# table
# {
#   border-collapse: collapse;
# }
# th
# {
#   color: #ffffff;
#   background-color: #000000;
# }
# td
# {
#   background-color: #cccccc;
# }
# table, th, td
# {
#   font-family:Arial, Helvetica, sans-serif;
#   border: 1px solid black;
#   text-align: right;
# }
#
# </style>
#
# <div id="fig_el236341400052355552965485731847"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
# ...
